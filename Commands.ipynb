# %% [markdown]
# https://github.com/menzelab/implicit-shape-reconstruction

# %% [markdown]
# CUDA_VISIBLE_DEVICES=0,1 python train.py -p ./paths_config_default.yml  -c ./train_config_default.yml
#
# CUDA_VISIBLE_DEVICES=1 python eval.py -p ./paths_config_default.yml  -c ./eval_config_default.yml -m ./models/DIASEM_test

# %% [markdown]
# CUDA_VISIBLE_DEVICES=0 python eval.py -p ./paths_config_diasem.yml  -c ./eval_config_diasem.yml -m DIASEM_RF
#
# CUDA_VISIBLE_DEVICES=0,1 python eval.py -p ./paths_config_diasem.yml  -c ./eval_config_diasem.yml -m DIASEM_RF_SIN_activation_healthy_set1
# DIASEM_RF_SIREN_activation_healthy_set1
# DIASEM_RF_healthy_set1_centered
# DIASEM_RF_SIREN_activation_omega10_healthy_set1
# DIASEM_RF_old_w_clinicalInfos
#
# DIASEM_RF_old_wo_clinicalInfos
# DIASEM_RF_young_w_clinicalInfos
#
#
# CUDA_VISIBLE_DEVICES=0,1 python train.py -p ./paths_config_diasem.yml  -c ./train_config_diasem.yml
#
# CUDA_VISIBLE_DEVICES=0 python train.py -p ./paths_config_default.yml  -c ./train_config_default.yml
# CUDA_VISIBLE_DEVICES=0 python eval.py -p ./paths_config_default.yml  -c ./train_config_default.yml -m model_name

# %%
CUDA_VISIBLE_DEVICES=0,1 python eval.py -p ./paths_config_diasem.yml  -c ./eval_config_diasem.yml -m DIASEM_RF_healthy_set2

# %%
CUDA_VISIBLE_DEVICES=0,1 python eval.py -p ./paths_config_fulgur.yml  -c ./eval_config_fulgur.yml -m FULGUR_label4_RF_minSlices_80
