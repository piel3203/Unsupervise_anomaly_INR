# %%
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from skimage import measure

import pandas as pd
import seaborn as sns
import matplotlib

# %%
matplotlib.rcParams['pdf.fonttype'] = 42  # Use Type 42 (TrueType) instead of Type 3
matplotlib.rcParams['ps.fonttype'] = 42  # Use Type 42 for .eps as well

# %%
# Define your volume calculation function
# Define the volume calculation function
def volume_calc(prediction, spacing):
    # Calculate the total volume in milliliters
    volume = np.sum(prediction > 0) * (spacing[0] * spacing[1] * spacing[2]) * 0.001
    return volume

# %%
pwd
# Out:
# '/home/jupyter-piecuch-l/ImplicitFunction/casename_files/DIASEM/RF'

# %%
# Load IDs from text file
id_file_path = "./sarcopenia_subj_DIASEM.txt"
with open(id_file_path, "r") as f:
    ids = [line.strip() for line in f if line.strip()]  # Read each line and strip whitespace

# Directory containing the .nii.gz files
directory = "../../../data/data_DIASEM/renamed_data/RF/"

# %%
id_file_path
# Out:
# './sarcopenia_subj_DIASEM.txt'

# %%
# Initialize lists to hold data for the DataFrame
data = []

# Loop through IDs, calculate volumes, and store data
for id in ids:
    filename = f"{id}.nii.gz"  # assuming the filename pattern
    #print(filename)
    file_path = os.path.join(directory, filename)
    
    if os.path.exists(file_path):
        print(filename)
        img = nib.load(file_path)
        data_array = img.get_fdata()
        spacing = img.header.get_zooms()[:3]
        volume = volume_calc(data_array, spacing)
        data.append({"ID": id, "Volume": volume, "Group": "Sarcopenia Dataset"})
# Out:
# AL135_RF.nii.gz
# AM112_RF.nii.gz
# BA137_RF.nii.gz
# BM103_RF.nii.gz
# CY164_RF.nii.gz
# DI154_RF.nii.gz
# DP172_RF.nii.gz
# DR160_RF.nii.gz
# EM151_RF.nii.gz
# EP105_RF.nii.gz
# FO117_RF.nii.gz
# GD171_RF.nii.gz
# LA134_RF.nii.gz
# LA162_RF.nii.gz
# LJ139_RF.nii.gz
# LP133_RF.nii.gz
# MA119_RF.nii.gz
# MM170_RF.nii.gz
# PG161_RF.nii.gz
# PP104_RF.nii.gz
# QP108_RF.nii.gz
# RA150_RF.nii.gz
# RJ136_RF.nii.gz
# SC146_RF.nii.gz

# %%
# Create a DataFrame from the data
df = pd.DataFrame(data)

# %%
df
# Out:
#           ID      Volume               Group
# 0   AL135_RF   97.397588  Sarcopenia Dataset
# 1   AM112_RF  128.531558  Sarcopenia Dataset
# 2   BA137_RF   83.490005  Sarcopenia Dataset
# 3   BM103_RF   50.829958  Sarcopenia Dataset
# 4   CY164_RF  118.219920  Sarcopenia Dataset
# 5   DI154_RF  102.682298  Sarcopenia Dataset
# 6   DP172_RF   70.962689  Sarcopenia Dataset
# 7   DR160_RF  162.587164  Sarcopenia Dataset
# 8   EM151_RF   94.362104  Sarcopenia Dataset
# 9   EP105_RF  117.843432  Sarcopenia Dataset
# 10  FO117_RF   58.541976  Sarcopenia Dataset
# 11  GD171_RF   90.324508  Sarcopenia Dataset
# 12  LA134_RF   65.699970  Sarcopenia Dataset
# 13  LA162_RF   68.379898  Sarcopenia Dataset
# 14  LJ139_RF   69.914632  Sarcopenia Dataset
# 15  LP133_RF   82.144447  Sarcopenia Dataset
# 16  MA119_RF   88.752543  Sarcopenia Dataset
# 17  MM170_RF   96.902528  Sarcopenia Dataset
# 18  PG161_RF   79.120612  Sarcopenia Dataset
# 19  PP104_RF   91.574046  Sarcopenia Dataset
# 20  QP108_RF   78.080015  Sarcopenia Dataset
# 21  RA150_RF  102.008098  Sarcopenia Dataset
# 22  RJ136_RF   72.454922  Sarcopenia Dataset
# 23  SC146_RF  113.317313  Sarcopenia Dataset

# %%
# Plotting the boxplot with seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(x="Group", y="Volume", data=df, color="skyblue")

# Overlay individual volume values as points
sns.stripplot(x="Group", y="Volume", data=df, color="darkblue", jitter=0.2, size=5)

# Add horizontal grid lines
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Add labels and title
plt.xlabel("Dataset")
plt.ylabel("Volume (mL)")
plt.title("Volume Distribution for Sarcopenia Dataset")
plt.show()

# %% [markdown]
# volumes = []
#
# # Loop through each ID and find the matching files
# for id in ids:
#     filename = f"{id}_RF.nii.gz"
#     print(filename)
#     file_path = os.path.join(directory, filename)
#
#     if os.path.exists(file_path):
#         # Load the file
#         img = nib.load(file_path)
#         data = img.get_fdata()
#         spacing = img.header.get_zooms()[:3]  # Get voxel spacing
#
#         # Calculate volume
#         vol = volume_calc(data, spacing)
#         volumes.append(vol)

# %%
# Load IDs from all.txt
id_file_path_all = "./RF_all_suj_ordonnes.txt"
with open(id_file_path_all, "r") as f:
    ids = [line.strip() for line in f if line.strip()]  # Read each line and strip whitespace

# Directory containing the .nii.gz files
directory = "../../../data/data_DIASEM/renamed_data/RF/"

# %%
# Initialize lists to hold data for the DataFrame
data_2 = []

# Separate IDs into two groups and calculate volumes
for id in ids:
    if id.startswith("sujet"):
        filename = f"{id}_3DUS.nii.gz"
        print(filename)
        group = "Healthy subjects"
    else:
        filename = f"{id}.nii.gz"
        print(filename)
        group = "Patients without sarcopenia"
    
    file_path = os.path.join(directory, filename)
    print (file_path)
    if os.path.exists(file_path):
        print (file_path)
        img = nib.load(file_path)
        data_array = img.get_fdata()
        spacing = img.header.get_zooms()[:3]
        volume = volume_calc(data_array, spacing)
        data_2 .append({"ID": id, "Volume (mL)": volume, "Group": group})

# Create a DataFrame from the data
df2 = pd.DataFrame(data_2 )
# Out:
# AL135_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/AL135_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/AL135_RF.nii.gz
# AM112_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/AM112_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/AM112_RF.nii.gz
# BA122_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BA122_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BA122_RF.nii.gz
# BA137_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BA137_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BA137_RF.nii.gz
# BC167_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BC167_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BC167_RF.nii.gz
# BH116_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BH116_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BH116_RF.nii.gz
# BJ128_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BJ128_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BJ128_RF.nii.gz
# BM103_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BM103_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BM103_RF.nii.gz
# BP149_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BP149_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/BP149_RF.nii.gz
# CG115_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CG115_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CG115_RF.nii.gz
# CG147_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CG147_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CG147_RF.nii.gz
# CR159_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CR159_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CR159_RF.nii.gz
# CS102_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CS102_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CS102_RF.nii.gz
# CY164_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CY164_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/CY164_RF.nii.gz
# DB145_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DB145_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DB145_RF.nii.gz
# DH156_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DH156_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DH156_RF.nii.gz
# DI154_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DI154_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DI154_RF.nii.gz
# DJ101_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DJ101_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DJ101_RF.nii.gz
# DO125_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DO125_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DO125_RF.nii.gz
# DP172_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DP172_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DP172_RF.nii.gz
# DR160_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DR160_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/DR160_RF.nii.gz
# EM151_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/EM151_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/EM151_RF.nii.gz
# EP105_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/EP105_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/EP105_RF.nii.gz
# FD121_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FD121_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FD121_RF.nii.gz
# FM144_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FM144_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FM144_RF.nii.gz
# FO117_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FO117_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/FO117_RF.nii.gz
# GD123_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GD123_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GD123_RF.nii.gz
# GD171_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GD171_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GD171_RF.nii.gz
# GG131_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GG131_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GG131_RF.nii.gz
# GG140_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GG140_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/GG140_RF.nii.gz
# HM124_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/HM124_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/HM124_RF.nii.gz
# IJ157_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/IJ157_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/IJ157_RF.nii.gz
# JJ142_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/JJ142_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/JJ142_RF.nii.gz
# LA134_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LA134_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LA134_RF.nii.gz
# LA162_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LA162_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LA162_RF.nii.gz
# LE120_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LE120_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LE120_RF.nii.gz
# LJ139_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LJ139_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LJ139_RF.nii.gz
# LJ168_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LJ168_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LJ168_RF.nii.gz
# LP133_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LP133_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/LP133_RF.nii.gz
# MA113_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MA113_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MA113_RF.nii.gz
# MA119_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MA119_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MA119_RF.nii.gz
# MM170_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MM170_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/MM170_RF.nii.gz
# PG161_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PG161_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PG161_RF.nii.gz
# PJ165_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PJ165_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PJ165_RF.nii.gz
# PL158_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PL158_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PL158_RF.nii.gz
# PP104_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PP104_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/PP104_RF.nii.gz
# QP108_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/QP108_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/QP108_RF.nii.gz
# RA126_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RA126_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RA126_RF.nii.gz
# RA150_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RA150_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RA150_RF.nii.gz
# RD132_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RD132_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RD132_RF.nii.gz
# RF148_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RF148_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RF148_RF.nii.gz
# RJ136_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RJ136_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RJ136_RF.nii.gz
# RY166_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RY166_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/RY166_RF.nii.gz
# SC146_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SC146_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SC146_RF.nii.gz
# SM127_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SM127_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SM127_RF.nii.gz
# SS130_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SS130_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/SS130_RF.nii.gz
# TC152_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/TC152_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/TC152_RF.nii.gz
# TT129_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/TT129_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/TT129_RF.nii.gz
# ZS153_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/ZS153_RF.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/ZS153_RF.nii.gz
# sujet10_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet10_RF_faible.nii.gz
# sujet10_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet10_RF_fort.nii.gz
# sujet10_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet10_RF_pad.nii.gz
# sujet11_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet11_RF_faible.nii.gz
# sujet11_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet11_RF_fort.nii.gz
# sujet11_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet11_RF_pad.nii.gz
# sujet12_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet12_RF_faible.nii.gz
# sujet12_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet12_RF_fort.nii.gz
# sujet12_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet12_RF_pad.nii.gz
# sujet13_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet13_RF_faible.nii.gz
# sujet13_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet13_RF_fort.nii.gz
# sujet13_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet13_RF_pad.nii.gz
# sujet14_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet14_RF_faible.nii.gz
# sujet14_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet14_RF_fort.nii.gz
# sujet14_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet14_RF_pad.nii.gz
# sujet15_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet15_RF_faible.nii.gz
# sujet15_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet15_RF_fort.nii.gz
# sujet15_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet15_RF_pad.nii.gz
# sujet1_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet1_RF_faible.nii.gz
# sujet1_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet1_RF_fort.nii.gz
# sujet1_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet1_RF_pad.nii.gz
# sujet2_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet2_RF_faible.nii.gz
# sujet2_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet2_RF_fort.nii.gz
# sujet2_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet2_RF_pad.nii.gz
# sujet3_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet3_RF_faible.nii.gz
# sujet3_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet3_RF_fort.nii.gz
# sujet3_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet3_RF_pad.nii.gz
# sujet4_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet4_RF_faible.nii.gz
# sujet4_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet4_RF_fort.nii.gz
# sujet4_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet4_RF_pad.nii.gz
# sujet5_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet5_RF_faible.nii.gz
# sujet5_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet5_RF_fort.nii.gz
# sujet5_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet5_RF_pad.nii.gz
# sujet6_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet6_RF_faible.nii.gz
# sujet6_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet6_RF_fort.nii.gz
# sujet6_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet6_RF_pad.nii.gz
# sujet7_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet7_RF_faible.nii.gz
# sujet7_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet7_RF_fort.nii.gz
# sujet7_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet7_RF_pad.nii.gz
# sujet8_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet8_RF_faible.nii.gz
# sujet8_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet8_RF_fort.nii.gz
# sujet8_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet8_RF_pad.nii.gz
# sujet9_RF_faible.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet9_RF_faible.nii.gz
# sujet9_RF_fort.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet9_RF_fort.nii.gz
# sujet9_RF_pad.nii.gz
# ../../../data/data_DIASEM/renamed_data/RF/sujet9_RF_pad.nii.gz

# %%
data_2
# Out:
# [{'ID': 'AL135_RF',
#   'Volume (mL)': 97.39758772209473,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'AM112_RF',
#   'Volume (mL)': 128.53155796125532,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BA122_RF',
#   'Volume (mL)': 103.02201010789443,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BA137_RF',
#   'Volume (mL)': 83.490004781208,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BC167_RF',
#   'Volume (mL)': 103.82952421785565,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BH116_RF',
#   'Volume (mL)': 79.3991206955365,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BJ128_RF',
#   'Volume (mL)': 113.43606457016058,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BM103_RF',
#   'Volume (mL)': 50.8299584500799,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'BP149_RF',
#   'Volume (mL)': 144.57387987449766,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'CG115_RF',
#   'Volume (mL)': 103.40257304482535,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'CG147_RF',
#   'Volume (mL)': 83.98519889195775,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'CR159_RF',
#   'Volume (mL)': 130.45712985608355,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'CS102_RF',
#   'Volume (mL)': 93.23047298061569,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'CY164_RF',
#   'Volume (mL)': 118.21991959713307,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DB145_RF',
#   'Volume (mL)': 153.60005286019714,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DH156_RF',
#   'Volume (mL)': 125.584985290654,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DI154_RF',
#   'Volume (mL)': 102.68229770965874,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DJ101_RF',
#   'Volume (mL)': 91.87280872804345,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DO125_RF',
#   'Volume (mL)': 74.55450922181365,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DP172_RF',
#   'Volume (mL)': 70.96268923619762,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'DR160_RF',
#   'Volume (mL)': 162.58716426150687,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'EM151_RF',
#   'Volume (mL)': 94.36210356975859,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'EP105_RF',
#   'Volume (mL)': 117.8434315613946,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'FD121_RF',
#   'Volume (mL)': 107.26270762519539,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'FM144_RF',
#   'Volume (mL)': 115.53216892430932,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'FO117_RF',
#   'Volume (mL)': 58.54197593215015,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'GD123_RF',
#   'Volume (mL)': 78.62353490549465,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'GD171_RF',
#   'Volume (mL)': 90.32450814341428,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'GG131_RF',
#   'Volume (mL)': 126.42590986313485,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'GG140_RF',
#   'Volume (mL)': 72.89022445596987,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'HM124_RF',
#   'Volume (mL)': 84.57964102879912,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'IJ157_RF',
#   'Volume (mL)': 86.11057958978694,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'JJ142_RF',
#   'Volume (mL)': 71.45277378562605,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LA134_RF',
#   'Volume (mL)': 65.69997023662926,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LA162_RF',
#   'Volume (mL)': 68.37989768335736,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LE120_RF',
#   'Volume (mL)': 147.0869778339565,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LJ139_RF',
#   'Volume (mL)': 69.91463201548252,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LJ168_RF',
#   'Volume (mL)': 145.23680575611257,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'LP133_RF',
#   'Volume (mL)': 82.1444466726361,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'MA113_RF',
#   'Volume (mL)': 83.71907358062965,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'MA119_RF',
#   'Volume (mL)': 88.75254320832435,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'MM170_RF',
#   'Volume (mL)': 96.9025276123709,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'PG161_RF',
#   'Volume (mL)': 79.12061176059582,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'PJ165_RF',
#   'Volume (mL)': 73.18656435164996,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'PL158_RF',
#   'Volume (mL)': 118.13968762247637,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'PP104_RF',
#   'Volume (mL)': 91.57404569274932,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'QP108_RF',
#   'Volume (mL)': 78.08001478681621,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RA126_RF',
#   'Volume (mL)': 73.41421421626117,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RA150_RF',
#   'Volume (mL)': 102.00809817179106,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RD132_RF',
#   'Volume (mL)': 139.66052936471533,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RF148_RF',
#   'Volume (mL)': 66.28871180418321,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RJ136_RF',
#   'Volume (mL)': 72.45492200284917,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'RY166_RF',
#   'Volume (mL)': 95.95139874144272,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'SC146_RF',
#   'Volume (mL)': 113.3173131317487,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'SM127_RF',
#   'Volume (mL)': 92.49713694928586,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'SS130_RF',
#   'Volume (mL)': 89.77774159733299,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'TC152_RF',
#   'Volume (mL)': 98.91698389776052,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'TT129_RF',
#   'Volume (mL)': 98.44049669399672,
#   'Group': 'Patients without sarcopenia'},
#  {'ID': 'ZS153_RF',
#   'Volume (mL)': 90.32415618082136,
#   'Group': 'Patients without sarcopenia'}]

# %%
df2
# Out:
#           ID      Volume                        Group
# 0   AL135_RF   97.397588  Patients without sarcopenia
# 1   AM112_RF  128.531558  Patients without sarcopenia
# 2   BA122_RF  103.022010  Patients without sarcopenia
# 3   BA137_RF   83.490005  Patients without sarcopenia
# 4   BC167_RF  103.829524  Patients without sarcopenia
# 5   BH116_RF   79.399121  Patients without sarcopenia
# 6   BJ128_RF  113.436065  Patients without sarcopenia
# 7   BM103_RF   50.829958  Patients without sarcopenia
# 8   BP149_RF  144.573880  Patients without sarcopenia
# 9   CG115_RF  103.402573  Patients without sarcopenia
# 10  CG147_RF   83.985199  Patients without sarcopenia
# 11  CR159_RF  130.457130  Patients without sarcopenia
# 12  CS102_RF   93.230473  Patients without sarcopenia
# 13  CY164_RF  118.219920  Patients without sarcopenia
# 14  DB145_RF  153.600053  Patients without sarcopenia
# 15  DH156_RF  125.584985  Patients without sarcopenia
# 16  DI154_RF  102.682298  Patients without sarcopenia
# 17  DJ101_RF   91.872809  Patients without sarcopenia
# 18  DO125_RF   74.554509  Patients without sarcopenia
# 19  DP172_RF   70.962689  Patients without sarcopenia
# 20  DR160_RF  162.587164  Patients without sarcopenia
# 21  EM151_RF   94.362104  Patients without sarcopenia
# 22  EP105_RF  117.843432  Patients without sarcopenia
# 23  FD121_RF  107.262708  Patients without sarcopenia
# 24  FM144_RF  115.532169  Patients without sarcopenia
# 25  FO117_RF   58.541976  Patients without sarcopenia
# 26  GD123_RF   78.623535  Patients without sarcopenia
# 27  GD171_RF   90.324508  Patients without sarcopenia
# 28  GG131_RF  126.425910  Patients without sarcopenia
# 29  GG140_RF   72.890224  Patients without sarcopenia
# 30  HM124_RF   84.579641  Patients without sarcopenia
# 31  IJ157_RF   86.110580  Patients without sarcopenia
# 32  JJ142_RF   71.452774  Patients without sarcopenia
# 33  LA134_RF   65.699970  Patients without sarcopenia
# 34  LA162_RF   68.379898  Patients without sarcopenia
# 35  LE120_RF  147.086978  Patients without sarcopenia
# 36  LJ139_RF   69.914632  Patients without sarcopenia
# 37  LJ168_RF  145.236806  Patients without sarcopenia
# 38  LP133_RF   82.144447  Patients without sarcopenia
# 39  MA113_RF   83.719074  Patients without sarcopenia
# 40  MA119_RF   88.752543  Patients without sarcopenia
# 41  MM170_RF   96.902528  Patients without sarcopenia
# 42  PG161_RF   79.120612  Patients without sarcopenia
# 43  PJ165_RF   73.186564  Patients without sarcopenia
# 44  PL158_RF  118.139688  Patients without sarcopenia
# 45  PP104_RF   91.574046  Patients without sarcopenia
# 46  QP108_RF   78.080015  Patients without sarcopenia
# 47  RA126_RF   73.414214  Patients without sarcopenia
# 48  RA150_RF  102.008098  Patients without sarcopenia
# 49  RD132_RF  139.660529  Patients without sarcopenia
# 50  RF148_RF   66.288712  Patients without sarcopenia
# 51  RJ136_RF   72.454922  Patients without sarcopenia
# 52  RY166_RF   95.951399  Patients without sarcopenia
# 53  SC146_RF  113.317313  Patients without sarcopenia
# 54  SM127_RF   92.497137  Patients without sarcopenia
# 55  SS130_RF   89.777742  Patients without sarcopenia
# 56  TC152_RF   98.916984  Patients without sarcopenia
# 57  TT129_RF   98.440497  Patients without sarcopenia
# 58  ZS153_RF   90.324156  Patients without sarcopenia

# %%
# Change column name in df2
df2.rename(columns={'Volume (mL)': 'Volume'}, inplace=True)

# %%
# Combine all three DataFrames
final_combined_df = pd.concat([df, df2], ignore_index=True)

# %%
final_combined_df
# Out:
#           ID      Volume                        Group
# 0   AL135_RF   97.397588           Sarcopenia Dataset
# 1   AM112_RF  128.531558           Sarcopenia Dataset
# 2   BA137_RF   83.490005           Sarcopenia Dataset
# 3   BM103_RF   50.829958           Sarcopenia Dataset
# 4   CY164_RF  118.219920           Sarcopenia Dataset
# ..       ...         ...                          ...
# 78  SM127_RF   92.497137  Patients without sarcopenia
# 79  SS130_RF   89.777742  Patients without sarcopenia
# 80  TC152_RF   98.916984  Patients without sarcopenia
# 81  TT129_RF   98.440497  Patients without sarcopenia
# 82  ZS153_RF   90.324156  Patients without sarcopenia
#
# [83 rows x 3 columns]

# %%
print(final_combined_df.columns)
# Out:
# Index(['ID', 'Volume', 'Group'], dtype='object')

# %%
final_combined_df.columns = final_combined_df.columns.str.strip()

# %%
# Create a boxplot with improved colors
plt.figure(figsize=(10, 6))
sns.boxplot(x="Group", y="Volume", data=final_combined_df, palette="Set1", fliersize=0)  # Using fliersize=0 to hide outliers from the boxplot

# Add individual data points using stripplot
sns.stripplot(x="Group", y="Volume", data=final_combined_df, color="black", alpha=0.6, size=5, jitter=True)

# Add horizontal lines at the median for each group
for group in final_combined_df['Group'].unique():
    median = final_combined_df[final_combined_df['Group'] == group]['Volume'].median()
    plt.axhline(median, linestyle='--', color='gray', linewidth=1, label=f'{group} Median: {median:.2f} mL')

# Improve the appearance of the plot
plt.title("Volume Distribution by Group")
plt.ylabel("Volume (mL)")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2766448/373301780.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Group", y="Volume", data=final_combined_df, palette="Set1", fliersize=0)  # Using fliersize=0 to hide outliers from the boxplot

# %%
final_combined_df
# Out:
#           ID      Volume                        Group
# 0   AL135_RF   97.397588           Sarcopenia Dataset
# 1   AM112_RF  128.531558           Sarcopenia Dataset
# 2   BA137_RF   83.490005           Sarcopenia Dataset
# 3   BM103_RF   50.829958           Sarcopenia Dataset
# 4   CY164_RF  118.219920           Sarcopenia Dataset
# ..       ...         ...                          ...
# 78  SM127_RF   92.497137  Patients without sarcopenia
# 79  SS130_RF   89.777742  Patients without sarcopenia
# 80  TC152_RF   98.916984  Patients without sarcopenia
# 81  TT129_RF   98.440497  Patients without sarcopenia
# 82  ZS153_RF   90.324156  Patients without sarcopenia
#
# [83 rows x 3 columns]

# %%
# Export the DataFrame to a CSV file
output_file_path = "./final_combined_df.csv"  # Specify your desired output file path
final_combined_df.to_csv(output_file_path, index=False)

print(f"DataFrame exported as {output_file_path}")
# Out:
# DataFrame exported as ./final_combined_df.csv

# %%
# List of folds for training and testing
folds = [1, 2, 3, 4, 5]

# Initialize a list to hold the data for each fold
folds_data = []

# Directory containing the text files for folds
train_directory = "./"
test_directory = "./"

# %%
# Initialize a list to hold data for each fold
folds_data = []

# Iterate over the specified folds
for fold in folds:
    print(fold)
    
    # Read training subjects for the current fold
    with open(os.path.join(train_directory, f'train_cases_{fold}.txt')) as f:
        train_subjects = [line.strip() for line in f.readlines()]
        
    # Read testing subjects for the current fold
    with open(os.path.join(test_directory, f'test_cases_{fold}.txt')) as f:
        test_subjects = [line.strip() for line in f.readlines()]
        #print("Test Subjects:", test_subjects)
    
    # Filter final_combined_df for training volumes
    train_volumes = final_combined_df[final_combined_df['ID'].isin(train_subjects)][['ID', 'Group', 'Volume']].copy()
    train_volumes['Fold'] = fold  # Add a Fold column
    train_volumes['Type'] = 'Train'  # Add a Type column for differentiation
    #print("Train Volumes:", train_volumes.head())
    
    # Filter final_combined_df for testing volumes
    test_volumes = final_combined_df[final_combined_df['ID'].isin(test_subjects)][['ID', 'Group', 'Volume']].copy()
    test_volumes['Fold'] = fold  # Add a Fold column
    test_volumes['Type'] = 'Test'  # Add a Type column for differentiation
    #print("Test Volumes:", test_volumes.head())
    
    # Combine the train and test volumes for this fold
    combined_volumes = pd.concat([train_volumes, test_volumes], ignore_index=True)
    folds_data.append(combined_volumes)

# Combine all folds data into a single DataFrame
final_folds_df = pd.concat(folds_data, ignore_index=True)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
final_folds_df
# Out:
#            ID                        Group      Volume  Fold   Type
# 0    BA122_RF  Patients without sarcopenia  103.022010     1  Train
# 1    BC167_RF  Patients without sarcopenia  103.829524     1  Train
# 2    BH116_RF  Patients without sarcopenia   79.399121     1  Train
# 3    BJ128_RF  Patients without sarcopenia  113.436065     1  Train
# 4    BP149_RF  Patients without sarcopenia  144.573880     1  Train
# ..        ...                          ...         ...   ...    ...
# 170  FM144_RF  Patients without sarcopenia  115.532169     5   Test
# 171  JJ142_RF  Patients without sarcopenia   71.452774     5   Test
# 172  PL158_RF  Patients without sarcopenia  118.139688     5   Test
# 173  RF148_RF  Patients without sarcopenia   66.288712     5   Test
# 174  ZS153_RF  Patients without sarcopenia   90.324156     5   Test
#
# [175 rows x 5 columns]

# %%
# Export the DataFrame to a CSV file
output_file_path = "./final_folds_df.csv"  # Specify your desired output file path
final_folds_df.to_csv(output_file_path, index=False)

print(f"DataFrame exported as {output_file_path}")
# Out:
# DataFrame exported as ./final_folds_df.csv

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Get unique folds from the DataFrame
unique_folds = final_folds_df['Fold'].unique()

# Create boxplots for each fold
for fold in unique_folds:
    plt.figure(figsize=(12, 6))

    # Filter the data for the current fold
    fold_data = final_folds_df[final_folds_df['Fold'] == fold]
    
    # Plot for training data
    train_data = fold_data[fold_data['Type'] == 'Train']
    
    plt.subplot(1, 2, 1)
    sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
    plt.title(f'Fold {fold}: Training Volumes by Group')
    plt.ylabel('Volume (mL)')
    
    # Plot for testing data
    test_data = fold_data[fold_data['Type'] == 'Test']
    
    plt.subplot(1, 2, 2)
    sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")
    plt.title(f'Fold {fold}: Testing Volumes by Group')
    plt.ylabel('Volume (mL)')

    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_2766448/1765882060.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_data, x='Group', y='Volume', palette="Set2")
# /tmp/ipykernel_2766448/1765882060.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=test_data, x='Group', y='Volume', palette="Set2")

# %%
# Create a new column to define categories for plotting
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Patients without sarcopenia"
    else:
        return f"{row['Type']} / Healthy Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(16, 8))

# Create a boxplot
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', palette="Set2", dodge=True)

# Add vertical lines to separate folds
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Customize the plot
plt.title('Volume Distribution by Fold, Category (Train/Test and Group)')
plt.xlabel('Fold')
plt.ylabel('Volume (mL)')
plt.legend(title='Category', loc='upper right')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
final_combined_df
# Out:
#           ID      Volume                        Group
# 0   AL135_RF   97.397588           Sarcopenia Dataset
# 1   AM112_RF  128.531558           Sarcopenia Dataset
# 2   BA137_RF   83.490005           Sarcopenia Dataset
# 3   BM103_RF   50.829958           Sarcopenia Dataset
# 4   CY164_RF  118.219920           Sarcopenia Dataset
# ..       ...         ...                          ...
# 78  SM127_RF   92.497137  Patients without sarcopenia
# 79  SS130_RF   89.777742  Patients without sarcopenia
# 80  TC152_RF   98.916984  Patients without sarcopenia
# 81  TT129_RF   98.440497  Patients without sarcopenia
# 82  ZS153_RF   90.324156  Patients without sarcopenia
#
# [83 rows x 3 columns]

# %%
# Step 1: Create the sarcopenia_volumes DataFrame
sarcopenia_volumes = final_combined_df[final_combined_df['Group'] == 'Sarcopenia Dataset']

# Check the column names in sarcopenia_volumes
print("Columns in sarcopenia_volumes:", sarcopenia_volumes.columns)
# Out:
# Columns in sarcopenia_volumes: Index(['ID', 'Volume', 'Group'], dtype='object')

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Patients without sarcopenia"
    else:
        return f"{row['Type']} / Healthy Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(16, 8))

# Create a boxplot for final_folds_df
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', palette="Set2", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), y='Volume', hue='Category', palette="Set1", dodge=True)

# Customize the plot
plt.title('Volume Distribution by Fold, Category (Train/Test and Group)')
plt.xlabel('Fold / Group')
plt.ylabel('Volume (mL)')
plt.legend(title='Category', loc='upper right')
plt.xticks(rotation=45)

# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2766448/3900010414.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Patients without sarcopenia"
    else:
        return f"{row['Type']} / Healthy Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(16, 8))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Patients with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Patients with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.title('Volume Distribution by Fold, Category (Train/Test and Group)')
plt.ylabel('Volume (mL)')
plt.legend(title='Category', loc='upper right')
plt.xticks(rotation=45)

# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2766448/1723156292.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"
# /tmp/ipykernel_2766448/1723156292.py:42: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(22, 8))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Patients with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Patients with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.title('Volume Distribution by Fold, Category (Train/Test and Group)', fontsize=16)
plt.ylabel('Volume (mL)', fontsize=20)
plt.xlabel('Fold', fontsize=20)

# Position the legend outside the boxplot
plt.legend(title='Category', loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=16, title_fontsize=18)

# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'], fontsize=18)
plt.yticks(fontsize=18)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2766448/1167711626.py:30: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Older Adults without sarcopenia"
    else:
        return f"{row['Type']} / Younger Adults"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Older Adults with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(13, 8))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Older Adults with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Older Adults with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=18)
plt.legend(title='Category', loc='upper right', fontsize=18, title_fontsize=20)

# Adjust the x-ticks to include "Fold 1", "Fold 2", ..., and "Sarcopenia"
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)),
           [f"Fold {fold}" for fold in final_folds_df['Fold'].unique()] + ['Sarcopenia'], fontsize=18)

plt.yticks(fontsize=18)
plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Add title "Fig. 4" in the upper left
plt.text(-0.4, max(final_folds_df['Volume'].max(), sarcopenia_volumes['Volume'].max()) * 1.05, 
         "Fig. 4", fontsize=18, fontweight='bold')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_2766448/64249405.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Older Adults with sarcopenia"
# /tmp/ipykernel_2766448/64249405.py:42: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Step 1: Apply category assignment only to Fold 1
final_folds_df_fold1 = final_folds_df[final_folds_df['Fold'] == 1].copy()
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Older Adults without sarcopenia"
    else:
        return f"{row['Type']} / Younger Adults"

final_folds_df_fold1['Category'] = final_folds_df_fold1.apply(categorize, axis=1)

# Step 2: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Older Adults with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(10, 6))

# Create a boxplot for final_folds_df_fold1 with lighter colors
sns.boxplot(data=final_folds_df_fold1, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add a vertical line between fold1 and sarcopenia boxplot
plt.axvline(x=0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Older Adults with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Older Adults with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df_fold1, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=18)

# Adjust the legend: smaller size, positioned at the upper right
plt.legend(title='Category', loc='upper right', fontsize=13, title_fontsize=15, frameon=True)

# Adjust the x-ticks to include only "Fold 1" and "Sarcopenia"
plt.xticks([0, 1], ["Fold 1", "Sarcopenia"], fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()

# Add "Fig. 4" INSIDE the plot (upper left, relative to axes)
plt.gca().text(0.02, 0.95, "Fig. 4", fontsize=18, fontweight='bold', color='black', transform=plt.gca().transAxes)

# Save the figure as a PDF
plt.savefig('volume_distribution_fold1_sarcopenia.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_2766448/1598938415.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Older Adults with sarcopenia"
# /tmp/ipykernel_2766448/1598938415.py:39: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Patients without sarcopenia"
    else:
        return f"{row['Type']} / Healthy Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(13, 8))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Patients with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Patients with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
#plt.title('Volume Distribution by Fold, Category (Train/Test and Group)')
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=18)
plt.legend(title='Category', loc='upper right', fontsize=18, title_fontsize=20)


#plt.xticks(rotation=45)

# Adjust the x-ticks to include "Sarcopenia" as a category
# Adjust the x-ticks to include "Fold 1", "Fold 2", ..., and "Sarcopenia"
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)),
           [f"Fold {fold}" for fold in final_folds_df['Fold'].unique()] + ['Sarcopenia'], fontsize=18)

plt.yticks(fontsize=18)
plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_2766448/4185483668.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"
# /tmp/ipykernel_2766448/4185483668.py:42: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Patients without sarcopenia"
    else:
        return f"{row['Type']} / Healthy Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(23, 8))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Patients with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Patients with sarcopenia"])  # Ensures the correct color mapping

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=22)



# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'], fontsize=22)
plt.yticks(fontsize=18)

# Position the legend outside the boxplot
plt.legend(title='Category', loc='upper left', fontsize=16, title_fontsize=18)

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1572635/443965619.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = "Sarcopenia / Patients with sarcopenia"
# /tmp/ipykernel_1572635/443965619.py:42: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes),

# %%
# Step 2: Create a new column to define categories for plotting in final_folds_df
def categorize(row):
    if 'Patients without sarcopenia' in row['Group']:
        return f"{row['Type']} / Elderly without sarcopenia"
    else:
        return f"{row['Type']} / Young Subject"

final_folds_df['Category'] = final_folds_df.apply(categorize, axis=1)

# Step 3: Create categories for sarcopenia_volumes
sarcopenia_volumes.loc[:, 'Category'] = "Sarcopenia / Elderly with sarcopenia"

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(23, 10))

# Create a boxplot for final_folds_df with lighter colors
sns.boxplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
            palette="pastel", dodge=True)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, olor='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
sns.boxplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
            y='Volume', hue='Category', dodge=True, 
            palette={"Sarcopenia / Elderly with sarcopenia": "red"}, 
            hue_order=["Sarcopenia / Elderly with sarcopenia"])

# Add individual volume values as darker points without including them in the legend
sns.stripplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=22)

# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'], fontsize=22)
plt.yticks(fontsize=18)

# Position the legend higher in the figure to avoid overlapping outliers
plt.legend(title='Category', loc='upper center', bbox_to_anchor=(0.5, 1.25), 
           fontsize=18, title_fontsize=20, ncol=2)

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1572635/2056737222.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes.loc[:, 'Category'] = "Sarcopenia / Elderly with sarcopenia"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 24>()
#      23 # Add vertical lines to separate folds for final_folds_df
#      24 for i in range(len(final_folds_df['Fold'].unique()) - 1):
# ---> 25     plt.axvline(x=i + 0.5, olor='gray', linestyle='--', linewidth=1)
#      27 # Add a vertical line between folds and sarcopenia boxplot
#      28 plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/pyplot.py:2731, in axvline(x, ymin, ymax, **kwargs)
#    2729 @_copy_docstring_and_deprecators(Axes.axvline)
#    2730 def axvline(x: float = 0, ymin: float = 0, ymax: float = 1, **kwargs) -> Line2D:
# -> 2731     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/axes/_axes.py:855, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     852 scalex = (xx < xmin) or (xx > xmax)
#     854 trans = self.get_xaxis_transform(which='grid')
# --> 855 l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     856 self.add_line(l)
#     857 if scalex:
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/.local/lib/python3.9/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'olor'

# %%
import matplotlib 
# Use Type 1 fonts instead of Type 3 or TrueType (Type 42)
matplotlib.rcParams['pdf.fonttype'] = 42  # Force Type 1 fonts in PDF
matplotlib.rcParams['ps.fonttype'] = 42  # Force Type 1 fonts in EPS

# Use a standard Type 1 font like Times
matplotlib.rcParams['font.family'] = 'serif'
matplotlib.rcParams['font.serif'] = ['Times']

# %%
# Replace "Elderly" with "Older adults" and "Young Subject" with "Young adults" in the DataFrames
final_folds_df['Category'] = final_folds_df['Category'].replace({
    "Train / Elderly without sarcopenia": "Train / Older adults without sarcopenia",
    "Test / Elderly without sarcopenia": "Test / Older adults without sarcopenia",
    "Train / Young Subject": "Train / Young adults",
    "Test / Young Subject": "Test / Young adults"
})

sarcopenia_volumes['Category'] = sarcopenia_volumes['Category'].replace({
    "Sarcopenia / Elderly with sarcopenia": "Sarcopenia / Older adults with sarcopenia"
})

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplotsipplot(data=final_folds_df, x='Fold', y='Volume', hue='Category', 
              palette="Set2", dodge=True, alpha=0.9, size=5, jitter=True, color='black', 
              legend=False)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(data=sarcopenia_volumes, x=['Sarcopenia'] * len(sarcopenia_volumes), 
              y='Volume', hue='Category', dodge=True, 
              alpha=0.9, size=5, jitter=True, color='black', legend=False)

# Customize the plot
#plt.title('Volume Distribution by Fold, Category (Train/Test and Group)')
plt.xlabel('')
plt.ylabel('Volume (mL)')
plt.legend(title='Category', loc='upper right')
#plt.xticks(rotation=45)

# Adjust the x-ticks to include "Sarcopenia" as a category
plt.xticks(list(range(len(final_folds_df['Fold'].unique()) + 1)), 
           list(final_folds_df['Fold'].unique()) + ['Sarcopenia'])

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.figure(figsize=(23, 10))

# Create a boxplot for final_folds_df with lighter colors
boxplot1 = sns.boxplot(
    data=final_folds_df,
    x='Fold',
    y='Volume',
    hue='Category',
    palette="pastel",
    dodge=True
)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
boxplot2 = sns.boxplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    palette={"Sarcopenia / Older adults with sarcopenia": "red"},
    hue_order=["Sarcopenia / Older adults with sarcopenia"]
)

# Add individual volume values as darker points without including them in the legend
sns.stripplot(
    data=final_folds_df,
    x='Fold',
    y='Volume',
    hue='Category',
    palette="Set2",
    dodge=True,
    alpha=0.9,
    size=5,
    jitter=True,
    legend=False
)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    alpha=0.9,
    size=5,
    jitter=True,
    color='black',
    legend=False
)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=22)

# Adjust the x-ticks to include "Fold_1", "Fold_2", ..., "Sarcopenia" as categories
plt.xticks(
    list(range(len(final_folds_df['Fold'].unique()) + 1)),
    [f"Fold_{fold}" for fold in final_folds_df['Fold'].unique()] + ['Sarcopenia'],
    fontsize=22
)
plt.yticks(fontsize=18)

# Extract colors from the boxplots for the legend commends you print this screen for your records.


handles, labels = boxplot1.get_legend_handles_labels()
handles2, labels2 = boxplot2.get_legend_handles_labels()
handles.extend(handles2)
labels.extend(labels2)

# Reorder legend items to match desired order
desired_order = [
    "Train / Older adults without sarcopenia",
    "Test / Older adults without sarcopenia",
    "Train / Young adults",
    "Test / Young adults",
    "Sarcopenia / Older adults with sarcopenia"
]
handles = [handles[labels.index(label)] for label in desired_order]
labels = [label for label in desired_order]

# Create the legend with desired layout
plt.legend(
    handles=handles,
    labels=labels,
    loc='upper center',
    bbox_to_anchor=(0.5, 1.25),
    fontsize=22,
    title="Category",
    title_fontsize=24,
    ncol=3,
    handletextpad=1.5,
    columnspacing=2,
    frameon=False
)

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
#   File <tokenize>:34
#     list(final_folds_df['Fold'].unique()) + ['Sarcopenia'])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
final_folds_df = final_folds_df[final_folds_df['Fold'] == 1]

# %%
# Replace "Elderly" with "Older adults" and "Young Subject" with "Young adults" in the DataFrames
final_folds_df['Category'] = final_folds_df['Category'].replace({
    "Train / Elderly without sarcopenia": "Train / Older adults without sarcopenia",
    "Test / Elderly without sarcopenia": "Test / Older adults without sarcopenia",
    "Train / Young Subject": "Train / Young adults",
    "Test / Young Subject": "Test / Young adults"
})

sarcopenia_volumes['Category'] = sarcopenia_volumes['Category'].replace({
    "Sarcopenia / Elderly with sarcopenia": "Sarcopenia / Older adults with sarcopenia"
})

# Optional: Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a figure for the combined boxplots
plt.figure(figsize=(18, 10))

# Create a boxplot for final_folds_df with lighter colors
boxplot1 = sns.boxplot(
    data=final_folds_df,
    x='Fold',
    y='Volume',
    hue='Category',
    palette="pastel",
    dodge=True
)

# Add vertical lines to separate folds for final_folds_df
for i in range(len(final_folds_df['Fold'].unique()) - 1):
    plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=1)

# Add a vertical line between folds and sarcopenia boxplot
plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)

# Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
boxplot2 = sns.boxplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    palette={"Sarcopenia / Older adults with sarcopenia": "red"},
    hue_order=["Sarcopenia / Older adults with sarcopenia"]
)

# Add individual volume values as darker points without including them in the legend
sns.stripplot(
    data=final_folds_df,
    x='Fold',
    y='Volume',
    hue='Category',
    palette="Set2",
    dodge=True,
    alpha=0.9,
    size=5,
    jitter=True,
    legend=False
)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    alpha=0.9,
    size=5,
    jitter=True,
    color='black',
    legend=False
)

# Customize the plot
plt.xlabel('')
plt.ylabel('Volume (mL)', fontsize=20)

# Adjust the x-ticks to include "Fold_1", "Fold_2", ..., "Sarcopenia" as categories
plt.xticks(
    list(range(len(final_folds_df['Fold'].unique()) + 1)),
    [f"Fold_{fold}" for fold in final_folds_df['Fold'].unique()] + ['Sarcopenia'],
    fontsize=22
)
plt.yticks(fontsize=18)

# Extract colors from the boxplots for the legend commends you print this screen for your records.


handles, labels = boxplot1.get_legend_handles_labels()
handles2, labels2 = boxplot2.get_legend_handles_labels()
handles.extend(handles2)
labels.extend(labels2)

# Reorder legend items to match desired order
desired_order = [
    "Train / Older adults without sarcopenia",
    "Test / Older adults without sarcopenia",
    "Train / Young adults",
    "Test / Young adults",
    "Sarcopenia / Older adults with sarcopenia"
]
handles = [handles[labels.index(label)] for label in desired_order]
labels = [label for label in desired_order]

# Create the legend with a reduced size
plt.legend(
    handles=handles,
    labels=labels,
    loc='upper center',
    bbox_to_anchor=(0.5, 1.25),
    fontsize=18,  # Reduced font size for labels
    title="Category",
    title_fontsize=20,  # Reduced font size for title
    ncol=3,
    handletextpad=1.5,
    columnspacing=2,
    frameon=False,
    handlelength=1.5,  # Adjust handle length for smaller legend items
    markerscale=0.8  # Adjust marker size for smaller points in the legend
)

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_3381847/3725335606.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sarcopenia_volumes['Category'] = sarcopenia_volumes['Category'].replace({
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [64], in <cell line: 37>()
#      34 plt.axvline(x=len(final_folds_df['Fold'].unique()) - 0.5, color='black', linestyle='--', linewidth=2)
#      36 # Create a boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
# ---> 37 boxplot2 = sns.boxplot(
#      38     data=sarcopenia_volumes,
#      39     x=['Sarcopenia'] * len(sarcopenia_volumes),
#      40     y='Volume',
#      41     hue='Category',
#      42     dodge=True,
#      43     palette={"Sarcopenia / Older adults with sarcopenia": "red"},
#      44     hue_order=["Sarcopenia / Older adults with sarcopenia"]
#      45 )
#      47 # Add individual volume values as darker points without including them in the legend
#      48 sns.stripplot(
#      49     data=final_folds_df,
#      50     x='Fold',
#    (...)
#      58     legend=False
#      59 )
#
# File ~/.local/lib/python3.9/site-packages/seaborn/categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/.local/lib/python3.9/site-packages/seaborn/categorical.py:745, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     742     ax.add_container(BoxPlotContainer(artists))
#     744 legend_artist = _get_patch_legend_artist(fill)
# --> 745 self._configure_legend(ax, legend_artist, boxprops)
#
# UnboundLocalError: local variable 'boxprops' referenced before assignment

# %%
# Create a figure for the combined boxplots with reduced size
plt.figure(figsize=(23, 10))

# Create a boxplot for final_folds_df with lighter colors
boxplot1 = sns.boxplot(
    data=final_folds_df,
    x='Fold',
    y='Volume',
    hue='Category',
    palette="pastel",
    dodge=True,
    width=0.6  # Reduce the width of the boxplot for folds (adjust as needed)
)

# Create a smaller boxplot for sarcopenia_volumes, setting the color for Sarcopenia to red
boxplot2 = sns.boxplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    palette={"Sarcopenia / Older adults with sarcopenia": "red"},
    hue_order=["Sarcopenia / Older adults with sarcopenia"],
    width=0.4  # Smaller width for sarcopenia boxplot
)

# Add individual volume values for sarcopenia_volumes as darker points without including them in the legend
sns.stripplot(
    data=sarcopenia_volumes,
    x=['Sarcopenia'] * len(sarcopenia_volumes),
    y='Volume',
    hue='Category',
    dodge=True,
    alpha=0.9,
    size=4,  # Smaller point size for sarcopenia
    jitter=True,
    color='black',
    legend=False
)

# Continue with your existing plot adjustments, legends, and customization

plt.tight_layout()

# Save the figure as a PDF
plt.savefig('volume_distribution_by_fold_category.pdf', format='pdf')

# Show the plot
plt.show()
